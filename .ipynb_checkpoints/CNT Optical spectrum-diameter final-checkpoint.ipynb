# %% [markdown]
# #CNT Diameter determination by optical absorbance spectrum
#
# Carbon nanotubes (CNT), as one dimensional materials, have singularities in their density of states (DOS). Optical absorbance of the CNT is elevated at these energies because of the increased capacity. Peaks in the CNT's optical absorbance spectrum correspond to the singularity energies
#
# The carbon lattice contains
#
# Weisman, R. B., & Bachilo, S. M. (2003). Dependence of optical transition energies on structure for single-walled carbon nanotubes in aqueous suspension: An empirical Kataura plot. Nano Letters, 3(9), 1235–1238. doi:10.1021/nl034428i

# %%
# %matplotlib inline
import pandas as pd
pd.set_option('display.mpl_style', 'default')

# %%
bk_volspectrum = pd.read_csv('volumeabs.csv', index_col = 'Energy (eV)')
JH_update1 = pd.read_csv('20150204_JH_M24-131_R2b.csv', index_col = 'Energy (eV)')
JH_update2 = pd.read_csv('20150521_JH_S26-012_R2.csv', index_col = 'Energy (eV)')

# %%
fig = bk_volspectrum.plot(ylim = (0.05, 0.095))
JH_update2.plot(ax = fig, figsize = (15, 10), secondary_y = True, title = 'Semiconducting CNT Optical Absorbance', 
                mark_right = False, xlim = (0.8, 3.1))
